# %%
import json
import pandas as pd

# %%
with open('raw_data/annotations/train.json') as json_file:
    data = json.load(json_file)

# %%
df = pd.DataFrame(data['annotations'])

# %%
df
# Out:
#                                                   caption      id  image_id  \
# 0       ITS IS A BASIL LEAVES CONTAINER ITS CONTAINS T...       0         0
# 1       A green and white plastic condiment bottle con...       1         0
# 2       Quality issues are too severe to recognize vis...       2         0
# 3       A bottle of spices in a plastic container layi...       3         0
# 4           some basil leaves in a container on a counter       4         0
# ...                                                   ...     ...       ...
# 117150  The back of a plastic card such as a credit ca...  117150     23430
# 117151  A card is seen with a scratch strip to reveal ...  117151     23430
# 117152  The back of a gift card without the silver str...  117152     23430
# 117153  The back of a plastic money or credit card wit...  117153     23430
# 117154                  A gift card is on top of a table.  117154     23430
#
#         is_precanned  is_rejected  text_detected
# ...

# %%
df.to_excel('interim_data/train_annotations.xlsx', index=False)
